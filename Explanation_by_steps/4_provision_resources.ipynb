# %% [markdown]
# # Provision template
#
# Our `azd` template is ready for provisioning and deployment.
#
# We run `azd provision` to ensure that changes made are applied correctly and work as expected. The CLI runs `terraform plan`, then `terraform apply` commands.
#
# ![image.png](attachment:image.png)
#
# Then CLI invites me to check the provisioned resources in the Azure portal:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# In the Azure portal, I check if the resources are correctly provisioned. I made a small typo in the name of the web app but it does not affect the code.
#
# ![image.png](attachment:image.png)
#
# I also check the website and see this message:
#
# ![image-2.png](attachment:image-2.png)
#
# So, the provisioning went smoothly!
