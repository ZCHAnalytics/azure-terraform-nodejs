# %% [markdown]
# # Deploy the web app code
#
# I am now ready to deploy the application code to populated the website. I use 'azd deploy` command:
#
# The app was successfully deployed!
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Web app live!
#
# ![image.png](attachment:image.png)
