# %% [markdown]
# # Initialise the application source code
#
# I tried to use .NET package with `dotnet new webapp` command but it resulted in the 403 Error. After investigating, I found that .NET framework and Linux are not compatible. So I needed to make changes to the process.
#
# I use this Microsoft module for installing Node.js:
# https://learn.microsoft.com/en-us/azure/app-service/quickstart-nodejs?tabs=linux&pivots=development-environment-cli
#
#
#
# First I check if I have the necessary packages for Node.js deployment.

# %%
node --version

# %% [markdown]
# # Create Node.js application

# %%
# first command 
npx express-generator myExpressApp --view ejs

# second command 
cd myExpressApp

# third command 
npm install

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Start the development server with debug information.

# %%
(base) PS C:\Users\Anaya\cloud\azd_startup\azure-terraform-nodejs\myExpressApp> $env:DEBUG="myexpressapp:*"; npm start
>>

> myexpressapp@0.0.0 start
> node ./bin/www

  myexpressapp:server Listening on port 3000 +0ms
GET / 200 13.209 ms - 207
GET /stylesheets/style.css 200 7.706 ms - 111
GET /favicon.ico 404 3.025 ms - 1383

# %% [markdown]
# In a browser, navigate to http://localhost:3000.
# Now we have the application source code in our project directory! I can start working on the infrastructure as code files...

# %% [markdown]
# ![image.png](attachment:image.png)
