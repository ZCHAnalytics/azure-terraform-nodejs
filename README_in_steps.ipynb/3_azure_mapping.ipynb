# %% [markdown]
# # Update the azure.yaml file
#
# In the previous steps, I added the app source code and defines terraform files to create the corresponding infrastructure. I will now map the relationship between the app source code and the Azure resources in the provided `azure.yaml` file.
#
# Microsoft Learn provides the following definition to add to the yaml file.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# and I remove redundant comments and add the following information, making sure indentation is correct:

# %%
# Name of the application.
name: azd-starter

services:
  web:
  language: js
  project: ./
  host: appservice

infra:
  provider: terraform
