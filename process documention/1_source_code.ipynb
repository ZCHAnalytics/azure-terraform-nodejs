# %% [markdown]
# # Initialise the application source code
#
# Following this step went smoothly.
# Create a new src directory at the root, move into the new directory, create another directory `web` and move into there as well.
#
# ![image.png](attachment:image.png)
#
# Create a "ASP.NET COre Web App" template using .NET CLI command `dotnet new webapp`
#
# ![image-2.png](attachment:image-2.png)
#
# This populates the new created `src` directory with web application cofiguration files:
#
# ![image-3.png](attachment:image-3.png)
#
#
# Now we have the application source code in our project directory! I can start working on the infrastructure as code files...
